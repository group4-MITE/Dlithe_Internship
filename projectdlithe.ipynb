# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file=pd.read_csv("test2.csv")
print(file)
# Out:
#             State  District    Market              Commodity      variety  \
# 0         Gujarat    Amreli  Damnagar  Bhindi(Ladies Finger)       Bhindi
# 1         Gujarat    Amreli  Damnagar                Brinjal        Other
# 2         Gujarat    Amreli  Damnagar                Cabbage      Cabbage
# 3         Gujarat    Amreli  Damnagar            Cauliflower  Cauliflower
# 4         Gujarat    Amreli  Damnagar      Coriander(Leaves)    Coriander
# ...           ...       ...       ...                    ...          ...
# 23088  Uttrakhand  Haridwar   Roorkee                  Mango        Other
# 23089  Uttrakhand  Haridwar   Roorkee   Mousambi(Sweet Lime)        Other
# 23090  Uttrakhand  Haridwar   Roorkee         Pear(Marasebu)        Other
# 23091  Uttrakhand  Haridwar   Roorkee                 Potato        Other
# 23092  Uttrakhand  Haridwar   Roorkee                Pumpkin        Other
#
#         grade Arrival_Date  Min Price  Max Price  Modal Price
# 0         FAQ   27-07-2023     4100.0     4500.0       4350.0
# 1         FAQ   27-07-2023     2200.0     3000.0       2450.0
# 2         FAQ   27-07-2023     2350.0     3000.0       2700.0
# 3         FAQ   27-07-2023     7000.0     7500.0       7250.0
# 4         FAQ   27-07-2023     8400.0     9000.0       8850.0
# ...       ...          ...        ...        ...          ...
# 23088  Medium   02-08-2023      800.0     1200.0       1000.0
# 23089  Medium   02-08-2023     1500.0     2500.0       2000.0
# 23090  Medium   02-08-2023     2000.0     3000.0       2500.0
# 23091     FAQ   02-08-2023      900.0     1800.0       1500.0
# 23092     FAQ   02-08-2023      500.0      700.0        600.0
#
# [23093 rows x 10 columns]

# %%
d3=pd.DataFrame(file)
df=d3.drop(["variety","grade"],axis=1)
print(df)
# Out:
#             State  District    Market              Commodity Arrival_Date  \
# 0         Gujarat    Amreli  Damnagar  Bhindi(Ladies Finger)   27-07-2023
# 1         Gujarat    Amreli  Damnagar                Brinjal   27-07-2023
# 2         Gujarat    Amreli  Damnagar                Cabbage   27-07-2023
# 3         Gujarat    Amreli  Damnagar            Cauliflower   27-07-2023
# 4         Gujarat    Amreli  Damnagar      Coriander(Leaves)   27-07-2023
# ...           ...       ...       ...                    ...          ...
# 23088  Uttrakhand  Haridwar   Roorkee                  Mango   02-08-2023
# 23089  Uttrakhand  Haridwar   Roorkee   Mousambi(Sweet Lime)   02-08-2023
# 23090  Uttrakhand  Haridwar   Roorkee         Pear(Marasebu)   02-08-2023
# 23091  Uttrakhand  Haridwar   Roorkee                 Potato   02-08-2023
# 23092  Uttrakhand  Haridwar   Roorkee                Pumpkin   02-08-2023
#
#        Min Price  Max Price  Modal Price
# 0         4100.0     4500.0       4350.0
# 1         2200.0     3000.0       2450.0
# 2         2350.0     3000.0       2700.0
# 3         7000.0     7500.0       7250.0
# 4         8400.0     9000.0       8850.0
# ...          ...        ...          ...
# 23088      800.0     1200.0       1000.0
# 23089     1500.0     2500.0       2000.0
# 23090     2000.0     3000.0       2500.0
# 23091      900.0     1800.0       1500.0
# 23092      500.0      700.0        600.0
#
# [23093 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23093 entries, 0 to 23092
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         23093 non-null  object
#  1   District      23093 non-null  object
#  2   Market        23093 non-null  object
#  3   Commodity     23093 non-null  object
#  4   Arrival_Date  23093 non-null  object
#  5   Min Price     23093 non-null  float64
#  6   Max Price     23093 non-null  float64
#  7   Modal Price   23093 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# State           0
# District        0
# Market          0
# Commodity       0
# Arrival_Date    0
# Min Price       0
# Max Price       0
# Modal Price     0
# dtype: int64

# %%
df.head(6)
# Out:
#      State District    Market              Commodity Arrival_Date  Min Price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)   27-07-2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal   27-07-2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage   27-07-2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower   27-07-2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)   27-07-2023     8400.0
# 5  Gujarat   Amreli  Damnagar          Ginger(Green)   27-07-2023    11000.0
#
#    Max Price  Modal Price
# 0     4500.0       4350.0
# 1     3000.0       2450.0
# 2     3000.0       2700.0
# 3     7500.0       7250.0
# 4     9000.0       8850.0
# 5    14000.0      12500.0

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Arrival_Date', 'Min Price',
#        'Max Price', 'Modal Price'],
#       dtype='object')

# %%
data2=df.copy()

# %%
data2=data2.dropna()

# %%
data2["Arrival_Date"][1]
# Out:
# '27-07-2023'

# %%
str=data2["Arrival_Date"][1]
str2=str.split('-')
print(str)
print(str2)
print(str2[1])
# Out:
# 27-07-2023
# ['27', '07', '2023']
# 07

# %%
dict={1:'jan',2:'feb',3:'march',4:'april',5:'may',6:'june',7:'july',8:'august',9:'september',10:'october',11:'november',12:'december'}

# %%
month_column=[]

# %%
for i in data2['Arrival_Date']:
    str=i
    str2=str.split('-')
    month_column.append(dict[(int(str2[1]))])

print(month_column)
# Out:
# ['july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', 'july', ...

# %%
len(month_column)
# Out:
# 23093

# %%
data2["month_column"]=month_column

# %%
data2.head()
# Out:
#      State District    Market              Commodity Arrival_Date  Min Price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)   27-07-2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal   27-07-2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage   27-07-2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower   27-07-2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)   27-07-2023     8400.0
#
#    Max Price  Modal Price month_column
# 0     4500.0       4350.0         july
# 1     3000.0       2450.0         july
# 2     3000.0       2700.0         july
# 3     7500.0       7250.0         july
# 4     9000.0       8850.0         july

# %%
season_name=[]

# %%
for t in data2["month_column"]:
    if t=='november' or t=='feb'or t=='jan' or t=='december':
        season_name.append('winter')
    elif t=='march' or t=='may'or  t=='april':
        season_name.append('summer')
    elif t=="august" or t=="june"or t=="july" or t=="october"or t=="september":
        season_name.append('rainy')

# %%
data2["season_name"]=season_name

# %%
data2.head()
# Out:
#      State District    Market              Commodity Arrival_Date  Min Price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)   27-07-2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal   27-07-2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage   27-07-2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower   27-07-2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)   27-07-2023     8400.0
#
#    Max Price  Modal Price month_column season_name
# 0     4500.0       4350.0         july       rainy
# 1     3000.0       2450.0         july       rainy
# 2     3000.0       2700.0         july       rainy
# 3     7500.0       7250.0         july       rainy
# 4     9000.0       8850.0         july       rainy

# %%
day_week=[]

# %%
for r in data2["Arrival_Date"]:
    str=r
    de=pd.Timestamp(r)
    day=de.dayofweek
    day_week.append(day)
# Out:
# <ipython-input-25-4e773244715a>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   de=pd.Timestamp(r)

# %%
len(day_week)
# Out:
# 23093

# %%
data2["day"]=day_week

# %%
data2.head()
# Out:
#      State District    Market              Commodity Arrival_Date  Min Price  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)   27-07-2023     4100.0
# 1  Gujarat   Amreli  Damnagar                Brinjal   27-07-2023     2200.0
# 2  Gujarat   Amreli  Damnagar                Cabbage   27-07-2023     2350.0
# 3  Gujarat   Amreli  Damnagar            Cauliflower   27-07-2023     7000.0
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)   27-07-2023     8400.0
#
#    Max Price  Modal Price month_column season_name  day
# 0     4500.0       4350.0         july       rainy    3
# 1     3000.0       2450.0         july       rainy    3
# 2     3000.0       2700.0         july       rainy    3
# 3     7500.0       7250.0         july       rainy    3
# 4     9000.0       8850.0         july       rainy    3

# %%
data2=data2.drop('Arrival_Date',axis=1)

# %%
data2.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
#        'Modal Price', 'month_column', 'season_name', 'day'],
#       dtype='object')

# %%
data2=data2.head(23000)

# %%
import seaborn as sns
sns.boxplot(data2['Modal Price'])
# Out:
# <Axes: >

# %%
Q1=np.percentile(data2['Modal Price'],25,interpolation ="midpoint")
Q3=np.percentile(data2['Modal Price'],75,interpolation ="midpoint")
IQR=Q3-Q1
# Out:
# <ipython-input-34-d445380193dc>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1=np.percentile(data2['Modal Price'],25,interpolation ="midpoint")
# <ipython-input-34-d445380193dc>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3=np.percentile(data2['Modal Price'],75,interpolation ="midpoint")

# %%
upper = np.where(data2['Modal Price'] >= (Q3+1.5*IQR))
lower = np.where(data2['Modal Price']<= (Q1-1.5*IQR))
print(upper[0],lower[0])
# Out:
# [    5    10    11 ... 22970 22981 22984] []

# %%
data2.drop(upper[0],inplace=True)
data2.drop(lower[0],inplace=True)

# %%
print("New Shape:",data2.shape)
# Out:
# New Shape: (21608, 10)

# %%
sns.boxplot(data2['Modal Price'])
# Out:
# <Axes: >

# %%
df=data2.copy()

# %%
data2.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
#        'Modal Price', 'month_column', 'season_name', 'day'],
#       dtype='object')

# %%
import plotly.express as px

# %%
sns.relplot(data=df,x="State",y="Modal Price",hue="season_name",kind='line')

# %%
sns.relplot(data=df,x='District',y="Modal Price",hue="season_name",kind='line')

# %%
fig=px.bar(df,x='District',y="Modal Price",color="season_name",height=400)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="119e1336-2e27-4e85-8ee5-e47d9aa53f0a" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("119e1336-2e27-4e85-8ee5-e47d9aa53f0a")) {                    Plotly.newPlot(                        "119e1336-2e27-4e85-8ee5-e47d9aa53f0a",                        [{"alignmentgroup":"True","hovertemplate":"season_name=rainy\u003cbr\u003eDistrict=%{x}\u003cbr\u003eModal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rainy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"rainy","offsetgroup":"rainy","orientation":"v","showlegend":true,"textposition":"auto","x":["Amreli","Amreli","Amreli","Amreli","Amreli","Amreli","Amreli","Amreli","Amreli","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Kangra","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Alappuzha","Kohima","Kohima","Kohima","Kohima","Kohima","Kohima","Kohima","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Dhenkanal","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Chittorgarh","Rajasamand","Rajasamand","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","North Tripura","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Baghpat","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Bulandshahar","Hathras","Hathras","Meerut","Meerut","Meerut","Meerut","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Dehradoon","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Haridwar","Chittor","Cuddapah","Cuddapah","Cuddapah","East Godavari","East Godavari","East Godavari","East Godavari","Guntur","Guntur","Kurnool","Kurnool","Kurnool","Kurnool","Kurnool","Kurnool","Visakhapatnam","Visakhapatnam","Kishanganj","Kishanganj","Kishanganj","Kishanganj","Kishanganj","Kishanganj","Kishanganj","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Balodabazar","Bijapur","Bijapur","Bijapur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Bilaspur","Dhamtari","Dhamtari","Dhamtari","Dhamtari","Dhamtari","Kabirdham","Kabirdham","Kanker","Kanker","Kanker","Kanker","Kanker","Kanker","Kanker","Koria","Koria","Koria","Mungeli","Mungeli","Raigarh","Raigarh","Raigarh","Raipur","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Rajnandgaon","Surajpur","Surajpur","Amreli","Amreli","Amreli","Amreli","Amreli","Amreli","Amrel ...

# %%
data2.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
#        'Modal Price', 'month_column', 'season_name', 'day'],
#       dtype='object')

# %%
sns.relplot(data=df,x='Market',y='Modal Price',hue='season_name',kind='line')

# %%
dist=(data2['Commodity'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['Commodity']=data2['Commodity'].map(dictOfwords)

# %%
dist=(data2['State'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['State']=data2['State'].map(dictOfwords)

# %%
dist=(data2['District'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['District']=data2['District'].map(dictOfwords)

# %%
dist=(data2['Market'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['Market']=data2['Market'].map(dictOfwords)

# %%
dist=(data2['month_column'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['month_column']=data2['month_column'].map(dictOfwords)

# %%
dist=(data2['season_name'])
distset=set(dist)
dd=list(distset)
dictOfwords={dd[i] :i for i in range(0,len(dd))}
data2['season_name']=data2['season_name'].map(dictOfwords)

# %%
data2.head()
# Out:
#    State  District  Market  Commodity  Min Price  Max Price  Modal Price  \
# 0     14       172     997         42     4100.0     4500.0       4350.0
# 1     14       172     997        103     2200.0     3000.0       2450.0
# 2     14       172     997         55     2350.0     3000.0       2700.0
# 3     14       172     997        151     7000.0     7500.0       7250.0
# 4     14       172     997        100     8400.0     9000.0       8850.0
#
#    month_column  season_name  day
# 0             0            0    3
# 1             0            0    3
# 2             0            0    3
# 3             0            0    3
# 4             0            0    3

# %%
import matplotlib.pyplot as plt

# %%
dataplot=sns.heatmap(data2.corr(),cmap='YlGnBu',annot=True)

# %%
plt.show()

# %%
data2.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
#        'Modal Price', 'month_column', 'season_name', 'day'],
#       dtype='object')

# %%
features=data2[['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
        'month_column', 'season_name', 'day']]

# %%
labels=data2['Modal Price']

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(features,labels,test_size=0.2,random_state=2)

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
regr=RandomForestRegressor(max_depth=1000,random_state=0)
regr.fit(Xtrain,Ytrain)
# Out:
# RandomForestRegressor(max_depth=1000, random_state=0)

# %%
Xtest[0:1]
# Out:
#        State  District  Market  Commodity  Min Price  Max Price  month_column  \
# 12949     24       178     712        103      700.0      850.0             0
#
#        season_name  day
# 12949            0    0

# %%
y_pred=regr.predict(Xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Ytest,y_pred)
# Out:
# 0.9937534212378871

# %%
y_pred
# Out:
# array([ 793.  , 4153.7 , 1398.35, ..., 5462.4 , 3696.5 , 1250.75])

# %%
data2.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Min Price', 'Max Price',
#        'Modal Price', 'month_column', 'season_name', 'day'],
#       dtype='object')

# %%
Xtest[0:1]
# Out:
#        State  District  Market  Commodity  Min Price  Max Price  month_column  \
# 12949     24       178     712        103      700.0      850.0             0
#
#        season_name  day
# 12949            0    0

# %%
user_input=[[24	,178,	712,	103	,700.0,	850.0,	0,	0,	0]]

# %%
regr.predict(user_input)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# array([793.])
